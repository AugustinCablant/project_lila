# %%
# Some imports
import pandas as pd
import numpy 
import matplotlib.pyplot as plt
from functions import calorie_hist, preparation_time, cook_time, extract_h_mins

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## III. EDA on recipies

# %%
# You can download the dataset : "https://www.kaggle.com/datasets/wilmerarltstrmberg/recipe-dataset-over-2m"
df_recettes = pd.read_csv('DOWNLOAD/all_recipies.csv')
df_recettes.sample(5)
# Out:
#                      recipe_name  rating        reviews  \
# 18436         Wonderful Meatloaf     4.0    174 Reviews
# 30234    Root Beer Float Cookies     4.4      6 Reviews
# 21098  Gyudon Japanese Beef Bowl     4.2      9 Reviews
# 35035      Honey Baked Chicken I     4.2    147 Reviews
# 36541      Sweet Restaurant Slaw     4.8  2,469 Reviews
#
#                                              description  \
# 18436  This is my all time favorite recipe for meatlo...
# 30234  The perfect cookie for root beer lovers, soft ...
# 21098  This is basically a common Japanese fast food ...
# 35035  This recipe is over 27 years old. It is a clas...
# 36541  This sweet coleslaw recipe tastes like the sla...
#
#                     published_date prep_time   cook_time     total_time  \
# 18436     Updated on July 14, 2022    5 mins     45 mins        50 mins
# 30234   Published on June 19, 2020   15 mins      8 mins        23 mins
# ...

# %%
print("Il y a", df_recettes.shape[0], "recettes dans ce dataset.")
# Out:
# Il y a 76195 recettes dans ce dataset.

# %%
calorie_hist(df_recettes)

# %%
preparation_time(df_recettes)
# Out:
# /Users/augustincablant/Documents/GitHub/project_lila/functions.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['prep_time'] = dataframe['prep_time'].str.extract('(\d+)').astype(float)
# /Users/augustincablant/Documents/GitHub/project_lila/functions.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['prep_time'] = dataframe['prep_time'].astype('Int64')
