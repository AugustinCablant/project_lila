# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
URL = 'https://www.data.gouv.fr/fr/datasets/r/403c9108-dd0a-443d-9ed5-bca5f056fa8f'
df = pd.read_csv(URL, error_bad_lines=False, sep = ';')
df.head()
# Out:
# /var/folders/bt/r1dg46ys21lb57m4n4x11m6c0000gn/T/ipykernel_8282/4205805986.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(URL, error_bad_lines=False, sep = ';')
# /var/folders/bt/r1dg46ys21lb57m4n4x11m6c0000gn/T/ipykernel_8282/4205805986.py:2: DtypeWarning: Columns (2,7,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(URL, error_bad_lines=False, sep = ';')
#                             nomattribuant  idattribuant referencedecision  \
# 0  0131-CCOM-D801 Ministère de la culture  1.100460e+13        2102618661
# 1  0131-CCOM-D801 Ministère de la culture  1.100460e+13        2102671700
# 2  0131-CCOM-D801 Ministère de la culture  1.100460e+13        2102691650
# 3  0131-CCOM-D801 Ministère de la culture  1.100460e+13        2102645877
# 4  0131-CCOM-D801 Ministère de la culture  1.100460e+13        2102650450
#
#    numero_de_poste_ej nombeneficiaire idbeneficiaire_en_com  \
# 0                 1.0               #             556993001
# 1                 1.0               #             005354001
# 2                 1.0               #             551044001
# 3                 1.0               #            1422153001
# 4                 1.0               #            1354596001
#
#   idbeneficiairepersonnephysique idbeneficiaire libellebeneficiaire1  \
# 0                    Non affecté     1100000015     THEATRE DE L ILE
# 1                    Non affecté     1100017413   LA FOKESASORTE CIE
# 2                    Non affecté     1100019920                SIAPO
# 3                    Non affecté     1100026356      ASSOCIATION "A"
# 4                    Non affecté     1100026535          ART OF GAIA
#
#   libellebeneficiaire2  ...  montant             nature  referenceversement  \
# 0                    #  ...  45000.0  aide en numéraire           100010421
# 1   LA FOKESASORTE CIE  ...    838.0  aide en numéraire           100007357
# 2                    #  ...   2095.0  aide en numéraire           100008517
# 3                    #  ...  10000.0  aide en numéraire           100005553
# 4                    #  ...   4190.0  aide en numéraire           100006033
#
#   datesperiodeversement pourcentagesubvention centre_de_couts  \
# 0            2019-08-20                   1.0      CCDNC01988
# 1            2019-07-04                   1.0      CCDNC01988
# 2            2019-07-17                   1.0      CCDNC01988
# 3            2019-05-21                   1.0      CCDNC01988
# 4            2019-06-04                   1.0      CCDNC01988
#
#    descriptioncentredecouts      export_desc_longue siret au_titre_de_l_annee
# 0                    COM988  COM Nouvelle Calédonie   NaN                2019
# 1                    COM988  COM Nouvelle Calédonie   NaN                2019
# 2                    COM988  COM Nouvelle Calédonie   NaN                2019
# 3                    COM988  COM Nouvelle Calédonie   NaN                2019
# 4                    COM988  COM Nouvelle Calédonie   NaN                2019
#
# [5 rows x 22 columns]

# %%
df.columns.to_list()
# Out:
# ['nomattribuant',
#  'idattribuant',
#  'referencedecision',
#  'numero_de_poste_ej',
#  'nombeneficiaire',
#  'idbeneficiaire_en_com',
#  'idbeneficiairepersonnephysique',
#  'idbeneficiaire',
#  'libellebeneficiaire1',
#  'libellebeneficiaire2',
#  'objet1',
#  'objet2',
#  'montant',
#  'nature',
#  'referenceversement',
#  'datesperiodeversement',
#  'pourcentagesubvention',
#  'centre_de_couts',
#  'descriptioncentredecouts',
#  'export_desc_longue',
#  'siret',
#  'au_titre_de_l_annee']

# %%
df['nombeneficiaire'].unique()
# Out:
# array(['#', '84405706700010', '39913025100032', ..., '84166592000010',
#        '42251244200076', '47820598200018'], dtype=object)
